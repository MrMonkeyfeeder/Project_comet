# %% [markdown]
# # Учимся работать с Comet_ml

# %%
# Импортируем библиотеки
import pandas as pd 
import seaborn as sns
from matplotlib import pyplot as plt
from comet_ml import Experiment
     
# Загружаем эксперимент
experiment = Experiment(
    api_key="Su35NWiC1e2prhGzDQ77vw2lN",
    project_name="medical-appointment",
    workspace="mrmonkeyfeeder",)

# Читаем данные
df = pd.read_csv('data/KaggleV2-May-2016.csv')
df.head()

# Выделяем числовые признаки
numeric_data = df[['Age','Scholarship','Hipertension','Diabetes','Alcoholism','Handcap','SMS_received']]
numeric_data.head()
# Out:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/mrmonkeyfeeder/medical-appointment/96b00f37b2d9447095882e54c4226209
#    Age  Scholarship  Hipertension  Diabetes  Alcoholism  Handcap  SMS_received
# 0   62            0             1         0           0        0             0
# 1   56            0             0         0           0        0             0
# 2   62            0             0         0           0        0             0
# 3    8            0             0         0           0        0             0
# 4   56            0             1         1           0        0             0

# %% [markdown]
# ### Построим тепловую карту

# %%
# Тепловая карта корреляций числовых признаков
plt.figure(figsize=(12,12))
ax = sns.heatmap(numeric_data.corr(), annot=True)
ax.set_title("Тепловая карта корреляций числовых признаков")
experiment.log_figure(figure=plt)
plt.show()

# %%
# Завершаем эксперимент
experiment.end()
# Out:
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     url                   : https://www.comet.com/mrmonkeyfeeder/medical-appointment/96b00f37b2d9447095882e54c4226209
# COMET INFO:   Uploads:
# COMET INFO:     environment details : 1
# COMET INFO:     figures             : 1
# COMET INFO:     filename            : 1
# COMET INFO:     git metadata        : 1
# COMET INFO:     installed packages  : 1
# COMET INFO:     notebook            : 1
# COMET INFO:     source_code         : 1
# COMET INFO:
